# %% [markdown]
# <a href="https://colab.research.google.com/github/rht6226/DL/blob/main/UCI_HAR_Inception_GRU_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Loading the Preprocessed UCI HAR Mobile Dataset

# %%
import numpy as np
from keras.utils import to_categorical
import json
import matplotlib

# %%
class UciMobileDataset:
    def __init__(self, filepath):
        with np.load(filepath + 'uci.npz') as data:
            self.trainX = data['trainX']
            self.trainy = to_categorical(data['trainy'])
            self.testX = data['testX']
            self.testy = to_categorical(data['testy'])

    def summary(self):
        print("UCI Human Activity Recognition Dataset: ")
        print("Shape of training data = X:{}, y: {}".format(self.trainX.shape, self.trainy.shape))
        print("Shape of testing data = X:{}, y: {}".format(self.testX.shape, self.testy.shape))

# %%
uci = UciMobileDataset(filepath='/content/drive/My Drive/HAR Processed Data/UCI_HAR/')
uci.summary()
# Out:
# UCI Human Activity Recognition Dataset:
# Shape of training data = X:(7352, 128, 9), y: (7352, 6)
# Shape of testing data = X:(2947, 128, 9), y: (2947, 6)

# %% [markdown]
# # Inception based Model With GRU Layer

# %% [markdown]
# ## Model Training

# %%
import keras
from keras import regularizers
from keras.models import Sequential
from keras.layers import MaxPooling1D, Conv1D, Flatten, Dense, Concatenate, GRU, Input, InputLayer
from keras.utils.vis_utils import plot_model

# %%
class Incept1D(keras.Model):
    def __init__(self, c1, c2, c3, c4):
        super(Incept1D, self).__init__()
        self.p1_1x1_conv = Conv1D(filters=c1, kernel_size=1, activation='relu', padding='same')

        self.p2_1x1_conv = Conv1D(filters=c2[0], kernel_size=1, activation='relu', padding='same')
        self.p2_1x3_conv = Conv1D(filters=c2[1], kernel_size=3, activation='relu', padding='same')

        self.p3_1x1_conv = Conv1D(filters=c3[0], kernel_size=1, activation='relu', padding='same')
        self.p3_1x5_conv = Conv1D(filters=c3[1], kernel_size=3, activation='relu', padding='same')

        self.p4_1x3_maxpool = MaxPooling1D(pool_size=3, strides=1, padding='same')
        self.p4_1x1_conv = Conv1D(filters=c4, kernel_size=1, padding='same', activation='relu')


    def call(self, x):
        p1 = self.p1_1x1_conv(x)
        p2 = self.p2_1x3_conv(self.p2_1x1_conv(x))
        p3 = self.p3_1x5_conv(self.p3_1x1_conv(x))
        p4 = self.p4_1x1_conv(self.p4_1x3_maxpool(x))
        # Concatenate the outputs on the channel dimension
        return Concatenate()([p1, p2, p3, p4])

# %%
def get_model(trainX, trainy):
    n_timesteps, n_features, n_outputs = trainX.shape[1], trainX.shape[2], trainy.shape[1]

    # Model Definitions
    model = Sequential()
    # Input Layer
    model.add(InputLayer(input_shape=(n_timesteps, n_features)))
    model.add(Incept1D(64, (32, 64), (32, 64), 64))
    model.add(Incept1D(56, (32, 64), (32, 64), 64))
    model.add(Incept1D(32, (32, 56), (32, 56), 32))
    model.add(MaxPooling1D(pool_size=2, padding='same'))
    model.add(Incept1D(32, (16, 32), (16, 32), 24))
    model.add(MaxPooling1D(pool_size=2, padding='same'))
    model.add(GRU(120, return_sequences=True))
    model.add(GRU(40))
    model.add(Dense(n_outputs, activation='softmax',
                    kernel_regularizer=regularizers.l1_l2(l1=1e-5, l2=1e-4), 
                    bias_regularizer=regularizers.l2(1e-4), 
                    activity_regularizer=regularizers.l2(1e-5)
                    ))

    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

    # Print stuff
    print(model.summary())
    return model

# %%
model = get_model(uci.trainX, uci.trainy)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# incept1d_4 (Incept1D)        (None, 128, 256)          14336
# _________________________________________________________________
# incept1d_5 (Incept1D)        (None, 128, 248)          59704
# _________________________________________________________________
# incept1d_6 (Incept1D)        (None, 128, 176)          42736
# _________________________________________________________________
# max_pooling1d_9 (MaxPooling1 (None, 64, 176)           0
# _________________________________________________________________
# incept1d_7 (Incept1D)        (None, 64, 120)           18712
# _________________________________________________________________
# max_pooling1d_11 (MaxPooling (None, 32, 120)           0
# _________________________________________________________________
# gru_2 (GRU)                  (None, 32, 120)           87120
# _________________________________________________________________
# gru_3 (GRU)                  (None, 40)                19440
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 246
# =================================================================
# Total params: 242,294
# Trainable params: 242,294
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
plot_model(model, show_shapes=True, show_layer_names=True)

# %%
history_inception = model.fit(x=uci.trainX, y=uci.trainy, validation_data=(uci.testX, uci.testy), verbose=1, batch_size=64, epochs=30)
# Out:
# Epoch 1/30
# 115/115 [==============================] - 3s 26ms/step - loss: 0.5729 - accuracy: 0.7707 - val_loss: 0.2975 - val_accuracy: 0.8955
# Epoch 2/30
# 115/115 [==============================] - 2s 19ms/step - loss: 0.1797 - accuracy: 0.9328 - val_loss: 0.3099 - val_accuracy: 0.9046
# Epoch 3/30
# 115/115 [==============================] - 2s 19ms/step - loss: 0.1284 - accuracy: 0.9502 - val_loss: 0.3225 - val_accuracy: 0.8972
# Epoch 4/30
# 115/115 [==============================] - 2s 19ms/step - loss: 0.1220 - accuracy: 0.9521 - val_loss: 0.3635 - val_accuracy: 0.8962
# Epoch 5/30
# 115/115 [==============================] - 2s 19ms/step - loss: 0.1312 - accuracy: 0.9461 - val_loss: 0.2581 - val_accuracy: 0.9114
# Epoch 6/30
# 115/115 [==============================] - 2s 20ms/step - loss: 0.1065 - accuracy: 0.9539 - val_loss: 0.2543 - val_accuracy: 0.9148
# Epoch 7/30
# 115/115 [==============================] - 2s 19ms/step - loss: 0.1042 - accuracy: 0.9531 - val_loss: 0.2541 - val_accuracy: 0.9165
# Epoch 8/30
# 115/115 [==============================] - 2s 19ms/step - loss: 0.1081 - accuracy: 0.9533 - val_loss: 0.3052 - val_accuracy: 0.9046
# Epoch 9/30
# 115/115 [==============================] - 2s 19ms/step - loss: 0.1285 - accuracy: 0.9467 - val_loss: 0.2530 - val_accuracy: 0.9182
# Epoch 10/30
# 115/115 [==============================] - 2s 19ms/step - loss: 0.1099 - accuracy: 0.9531 - val_loss: 0.2405 - val_accuracy: 0.9162
# Epoch 11/30
# 115/115 [==============================] - 2s 19ms/step - loss: 0.1056 - accuracy: 0.9532 - val_loss: 0.2110 - val_accuracy: 0.9209
# Epoch 12/30
# 115/115 [==============================] - 2s 19ms/step - loss: 0.0942 - accuracy: 0.9577 - val_loss: 0.2509 - val_accuracy: 0.9233
# Epoch 13/30
# 115/115 [==============================] - 2s 19ms/step - loss: 0.0951 - accuracy: 0.9580 - val_loss: 0.2222 - val_accuracy: 0.9325
# Epoch 14/30
# 115/115 [==============================] - 2s 19ms/step - loss: 0.0902 - accuracy: 0.9580 - val_loss: 0.2244 - val_accuracy: 0.9332
# Epoch 15/30
# 115/115 [==============================] - 2s 20ms/step - loss: 0.0847 - accuracy: 0.9618 - val_loss: 0.2549 - val_accuracy: 0.9298
# Epoch 16/30
# 115/115 [==============================] - 2s 19ms/step - loss: 0.0822 - accuracy: 0.9621 - val_loss: 0.2546 - val_accuracy: 0.9247
# Epoch 17/30
# 115/115 [==============================] - 2s 19ms/step - loss: 0.1068 - accuracy: 0.9540 - val_loss: 0.2419 - val_accuracy: 0.9155
# Epoch 18/30
# 115/115 [==============================] - 2s 20ms/step - loss: 0.0833 - accuracy: 0.9611 - val_loss: 0.2477 - val_accuracy: 0.9308
# Epoch 19/30
# 115/115 [==============================] - 2s 19ms/step - loss: 0.0751 - accuracy: 0.9630 - val_loss: 0.2719 - val_accuracy: 0.9121
# Epoch 20/30
# 115/115 [==============================] - 2s 19ms/step - loss: 0.0774 - accuracy: 0.9657 - val_loss: 0.2292 - val_accuracy: 0.9277
# Epoch 21/30
# 115/115 [==============================] - 2s 19ms/step - loss: 0.0762 - accuracy: 0.9663 - val_loss: 0.2776 - val_accuracy: 0.9237
# Epoch 22/30
# 115/115 [==============================] - 2s 20ms/step - loss: 0.0726 - accuracy: 0.9661 - val_loss: 0.3904 - val_accuracy: 0.8890
# Epoch 23/30
# 115/115 [==============================] - 2s 19ms/step - loss: 0.0950 - accuracy: 0.9622 - val_loss: 0.2672 - val_accuracy: 0.9281
# Epoch 24/30
# 115/115 [==============================] - 2s 20ms/step - loss: 0.0692 - accuracy: 0.9693 - val_loss: 0.2981 - val_accuracy: 0.9172
# Epoch 25/30
# 115/115 [==============================] - 2s 19ms/step - loss: 0.0790 - accuracy: 0.9665 - val_loss: 0.2219 - val_accuracy: 0.9250
# Epoch 26/30
# 115/115 [==============================] - 2s 19ms/step - loss: 0.0713 - accuracy: 0.9684 - val_loss: 0.3066 - val_accuracy: 0.9267
# Epoch 27/30
# 115/115 [==============================] - 2s 19ms/step - loss: 0.0659 - accuracy: 0.9708 - val_loss: 0.2485 - val_accuracy: 0.9247
# Epoch 28/30
# 115/115 [==============================] - 2s 19ms/step - loss: 0.0603 - accuracy: 0.9725 - val_loss: 0.2874 - val_accuracy: 0.9209
# Epoch 29/30
# 115/115 [==============================] - 2s 20ms/step - loss: 0.0612 - accuracy: 0.9731 - val_loss: 0.3425 - val_accuracy: 0.9145
# Epoch 30/30
# 115/115 [==============================] - 2s 20ms/step - loss: 0.0696 - accuracy: 0.9706 - val_loss: 0.2384 - val_accuracy: 0.9253

# %%
# Saving the model
import tensorflow as tf    
tf.keras.models.save_model(
    model,
    "Inception_GRU_UCI_HAR.model",
    overwrite=True,
    include_optimizer=True
)

# %%
_, accuracy = model.evaluate(uci.testX, uci.testy, batch_size=64, verbose=1)
print("Accuracy for Inception and GRU based model = {}%".format(accuracy))
# Out:
# 47/47 [==============================] - 0s 9ms/step - loss: 0.2384 - accuracy: 0.9253
# Accuracy for Inception and GRU based model = 0.9253478050231934%

# %% [markdown]
# ## Plotting Accuracy

# %%
# Plotting Loss and Accuracy

import matplotlib.pyplot as plt

def plot_model_accuracy(details, history, figureSize=[8, 8]):
    matplotlib.rcParams['figure.figsize'] = figureSize
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy for {}'.format(details))
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

def plot_model_loss(details, history, figureSize=[8, 8]):
    matplotlib.rcParams['figure.figsize'] = figureSize
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss for {}'.format(details))
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

# %%
plot_model_accuracy("Inception-GRU Model on UCI Mobile dataset", history=history_inception)

# %%
plot_model_loss("Inception - GRU Model on UCI Mobile dataset", history=history_inception)

# %% [markdown]
# ## Plotting Confusion Matrix

# %%
# %matplotlib inline
from sklearn.metrics import confusion_matrix
import itertools
import matplotlib.pyplot as plt

# %%
def plot_cm(predictedY, testy, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Blues, figureSize=[10, 10]):
    matplotlib.rcParams['figure.figsize'] = figureSize
    # Predict Y, And get Confusion Matrix
    predictedY = np.argmax(predictedY, axis = 1)
    testy = np.argmax(testy, axis=1)
    cm = confusion_matrix(y_true=testy, y_pred=predictedY)

    # Plotting
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
            horizontalalignment="center",
            color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
# CNN Based Network
predictedY = model.predict(uci.testX)
cm_plot_labels = ['WALKING', 'WALKING_UPSTAIRS', 'WALKING_DOWNSTAIRS', 'SITTING', 'STANDING', 'LAYING']
plot_cm(predictedY, testy=uci.testy, classes=cm_plot_labels, title='Confusion Matrix for Inception-GRU based Model')
# Out:
# Confusion matrix, without normalization

# %% [markdown]
# ## Classification Report

# %%
from sklearn.metrics import classification_report

# %%
# 1D CNN based Model
predictedY = model.predict(uci.testX)
y_pred = np.argmax(predictedY, axis = 1)
y_true = np.argmax(uci.testy, axis=1)
target_names = ['WALKING', 'WALKING_UPSTAIRS', 'WALKING_DOWNSTAIRS', 'SITTING', 'STANDING', 'LAYING']
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
#                     precision    recall  f1-score   support
#
#            WALKING       0.98      0.96      0.97       496
#   WALKING_UPSTAIRS       0.97      0.99      0.98       471
# WALKING_DOWNSTAIRS       0.95      0.97      0.96       420
#            SITTING       0.80      0.85      0.82       491
#           STANDING       0.89      0.80      0.84       532
#             LAYING       0.96      1.00      0.98       537
#
#           accuracy                           0.93      2947
#          macro avg       0.93      0.93      0.93      2947
#       weighted avg       0.93      0.93      0.92      2947

# %% [markdown]
# ## Overall accuracy using Weighted F-Beta Score

# %%
from sklearn.metrics import precision_recall_fscore_support as score

# %%
predictedY = model.predict(uci.testX)
y_pred = np.argmax(predictedY, axis = 1)
y_true = np.argmax(uci.testy, axis=1)

precision,recall,fscore, _ = score(y_true,y_pred,average='macro')
print ('Precision : {}'.format(precision))
print ('Recall    : {}'.format(recall))
print ('F-score   : {}'.format(fscore))
# Out:
# Precision : 0.9264205845201637
# Recall    : 0.9274328066857659
# F-score   : 0.9262539563461933
